# %%
from IPython.core.display import HTML
table_css = 'table {align:left;display:block} '
HTML('<style>{}</style>'.format(table_css))
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('BankChurners.csv')
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df.rename(columns = 
          {'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1':'Naive_bayes_1',
          'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2':'Naive_bayes_2'}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %% [markdown]
# | ColumnName | Description |
# | :- | :- |
# | CLIENTNUM | Unique identifier for each customer. (Integer) |
# | Customer_Age | Age of customer. (Integer) |
# | Gender | Gender of customer. (String) |
# | Dependent_count | Number of dependents that customer has. (Integer) |
# | Education_Level | Education level of customer. (String) |
# | Marital_Status | Marital status of customer. (String) |
# | Card_Category | Type of card held by customer. (String) |
# | Months_on_book | How long customer has been on the books. (Integer) |
# | Total_Relationship_Count | Total number of relationships customer has with the credit card provider. (Integer) |
# | Months_Inactive_12_mon | Number of months customer has been inactive in the last twelve months. (Integer) |
# | Contacts_Count_12_mon | Number of contacts customer has had in the last twelve months. (Integer) |
# | Credit_Limit | Credit limit of customer. (Integer) |
# | Total_Revolving_Bal | Total revolving balance of customer. (Integer) |
# | Avg_Open_To_Buy | Average open to buy ratio of customer. (Integer) |
# | Total_Amt_Chng_Q4_Q1 | Total amount changed from quarter 4 to quarter 1. (Integer) |
# | Total_Trans_Amt | Total transaction amount. (Integer) |
# | Total_Trans_Ct | Total transaction count. (Integer) |
# | Total_Ct_Chng_Q4_Q1 | Total count changed from quarter 4 to quarter 1. (Integer) |
# | Avg_Utilization_Ratio | Average utilization ratio of customer. (Integer) |
# | Naive_bayes_1 | Naive Bayes classifier for predicting whether or not someone will churn based on characteristics such |

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
df['Gender'].value_counts()
# Out:
# F    5358
# M    4769
# Name: Gender, dtype: int64

# %%
df[['Naive_bayes_1', 'Naive_bayes_2']]
# Out:
#        Naive_bayes_1  Naive_bayes_2
# 0           0.000093       0.999910
# 1           0.000057       0.999940
# 2           0.000021       0.999980
# 3           0.000134       0.999870
# 4           0.000022       0.999980
# ...              ...            ...
# 10122       0.000191       0.999810
# 10123       0.995270       0.004729
# 10124       0.997880       0.002118
# 10125       0.996710       0.003294
# 10126       0.996620       0.003377
#
# [10127 rows x 2 columns]

# %%
df_upd = df.drop(['Naive_bayes_2'], axis = 1)
df_upd
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df_upd['Attrition_Flag'].value_counts()
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
sns.countplot(x = 'Attrition_Flag', data = df_upd, palette = 'Purples')
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
first_six = df_upd.iloc[:, :6]
first_six
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level
# 0         High School
# 1            Graduate
# ...

# %%
first_six[first_six['Gender'] == 'M']['Attrition_Flag'].value_counts()
# Out:
# Existing Customer    4072
# Attrited Customer     697
# Name: Attrition_Flag, dtype: int64

# %%
#Paired
plt.figure(figsize = (6,5))
sns.countplot(x = 'Attrition_Flag', data = df_upd, hue = 'Gender', palette = 'Purples')
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
first_six[first_six['Gender'] == 'F']['Attrition_Flag'].value_counts()
# Out:
# Existing Customer    4428
# Attrited Customer     930
# Name: Attrition_Flag, dtype: int64

# %%
df_upd['Customer_Age_upd'] = pd.cut(df['Customer_Age'], bins = [26, 40, 60, 73],
                                labels = ['Young', 'Middle-Aged', 'Old'])
df_upd
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df_upd.drop('Customer_Age', axis = 1, inplace = True)

# %%
df_upd['Customer_Age_upd'].value_counts()
# Out:
# Middle-Aged    7325
# Young          2319
# Old             405
# Name: Customer_Age_upd, dtype: int64

# %%
df2 = df_upd[df_upd['Attrition_Flag'] == 'Attrited Customer']
df2['Customer_Age_upd'].value_counts().loc['Young']
# Out:
# 336

# %%
def create_df(i):
    dic_entry = {}
    percentage = []
    tot_tran_list = []
    attr_cust = df_upd[df_upd['Attrition_Flag'] == 'Attrited Customer']
    index = df_upd[i].value_counts().index
    value_num = df_upd[i].value_counts()
    for j in index:
        attr_num = value_num.loc[j]
        no_of_attr = len(attr_cust[attr_cust[i] == j])
        tot_trans_cost = df_upd[df_upd[i] == j]['Total_Trans_Amt'].sum()
        percentage.append(no_of_attr / attr_num)
        tot_tran_list.append(tot_trans_cost)
        
    dic_entry['no_under_category'] = df_upd[i].value_counts().values
    dic_entry['percent_attrited'] = percentage
    dic_entry['total_trans_cost'] = tot_tran_list
    new_df = pd.DataFrame(dic_entry, index = index)
    return new_df
create_df('Customer_Age_upd')
# Out:
#              no_under_category  percent_attrited  total_trans_cost
# Middle-Aged               7325          0.167509          32991062
# Young                     2319          0.144890          10167295
# Old                        405          0.143210           1240067

# %%
create_df('Gender')
# Out:
#    no_under_category  percent_attrited  total_trans_cost
# F               5358          0.173572          23169697
# M               4769          0.146152          21430485

# %%
create_df('Marital_Status')
# Out:
#           no_under_category  percent_attrited  total_trans_cost
# Married                4687          0.151269          19560810
# Single                 3943          0.169414          18116328
# Unknown                 749          0.172230           3535284
# Divorced                748          0.161765           3387760

# %%
create_df('Income_Category')
# Out:
#                 no_under_category  percent_attrited  total_trans_cost
# Less than $40K               3561          0.171862          15538139
# $40K - $60K                  1790          0.151397           7886058
# $80K - $120K                 1535          0.157655           6881344
# $60K - $80K                  1402          0.134807           6239899
# Unknown                      1112          0.168165           4761819
# $120K +                       727          0.173315           3292923

# %%
create_df('Card_Category')
# Out:
#           no_under_category  percent_attrited  total_trans_cost
# Blue                   9436          0.160979          39870938
# Silver                  555          0.147748           3657718
# Gold                    116          0.181034            891531
# Platinum                 20          0.250000            179995

# %%
create_df('Education_Level')
# Out:
#                no_under_category  percent_attrited  total_trans_cost
# Graduate                    3128          0.155691          13821041
# High School                 2013          0.152012           8864729
# Unknown                     1519          0.168532           6714061
# Uneducated                  1487          0.159381           6668215
# College                     1013          0.152024           4311132
# Post-Graduate                516          0.178295           2329954
# Doctorate                    451          0.210643           1891050

# %%
#No of customers with more than 3 years history with bank
loyal_cust = df_upd[df_upd['Months_on_book'] >= 36]
len(loyal_cust)
# Out:
# 6325

# %%
#Percentage of customers churned with more than 3 years history with bank
len(loyal_cust[loyal_cust['Attrition_Flag'] == 'Attrited Customer']) / len(loyal_cust)
# Out:
# 0.16758893280632411

# %%
df.groupby('Attrition_Flag').mean().iloc[:, 2:]
# Out:
#                    Dependent_count  Months_on_book  Total_Relationship_Count  \
# Attrition_Flag
# Attrited Customer         2.402581       36.178242                  3.279656
# Existing Customer         2.335412       35.880588                  3.914588
#
#                    Months_Inactive_12_mon  Contacts_Count_12_mon  \
# Attrition_Flag
# Attrited Customer                2.693301               2.972342
# Existing Customer                2.273765               2.356353
#
#                    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# Attrition_Flag
# Attrited Customer   8136.039459           672.822987      7463.216472
# Existing Customer   8726.877518          1256.604118      7470.273400
#
#                    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# Attrition_Flag
# Attrited Customer              0.694277      3095.025814       44.933620
# Existing Customer              0.772510      4654.655882       68.672588
#
# ...
